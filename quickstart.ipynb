# %%
#example 
from phase_extender.hapstats import compute_haplotype_stats, compute_stats_df, plot_all_data, plot_hist_one_chr, plot_bar_hapstats
import pandas as pd

# %%
initial_hap_df = pd.read_csv('tests/outdir/eg3out/initial_haplotype_stats_ms02g.txt', sep='\t')
initial_hap_df
# Out:
#    CHROM                    ms02g:PI            num_Vars_by_PI  \
# 0      1                         1,2                      60,6
# 1      2                 9,8,10,7,11            94,78,10,69,25
# 2      3                     5,3,4,6                6,12,14,17
# 3      4        17,18,22,16,19,21,20         22,11,3,16,7,12,6
# 4      5                 13,15,12,14              56,25,96,107
# 5      7  24,26,29,25,27,23,30,28,31  12,31,19,6,12,23,9,37,25
# 6      8                       33,32                     53,35
#
#                               range_of_PI  total_haplotypes  total_Vars
# 0                                 2820,81                 2          66
# 1           89910,1102167,600,1621365,636                 5         276
# 2                      908,394,759,115656                 4          49
# 3            1463,171,149,256,157,388,195                 7          77
# 4                   2600821,858,5666,1792                 4         284
# 5  968,3353,489,116,523,1933,823,2655,331                 9         174
# 6                            1603,2991338                 2          88

# %%
plot_all_data(initial_hap_df, soi='ms02g', prefix='initial',show_plot=True )

# %%
final_hap_df = pd.read_csv('tests/outdir/eg3out/final_haplotype_stats_ms02g.txt', sep='\t')
final_hap_df
# Out:
#    CHROM  ms02g:PI num_Vars_by_PI            range_of_PI  total_haplotypes  \
# 0      1         1             66                   2903                 1
# 1      2    9,8,10      94,78,104  89910,1102167,1622052                 3
# 2      3       5,3           6,43             908,117261                 2
# 3      4        17             77                   4027                 1
# 4      5        13            284                9642559                 1
# 5      7  24,29,31      43,106,25          4342,6798,331                 3
# 6      8     33,32          53,35           1603,2991338                 2
#
#    total_Vars
# 0          66
# 1         276
# 2          49
# 3          77
# 4         284
# 5         174
# 6          88

# %%
plot_all_data(final_hap_df, soi='ms02g', prefix='final',show_plot=True )

# %%
xcol="CHROM"
ycol="total_Vars"
plot_bar_hapstats(final_hap_df, xcol, ycol, filepath='chrome_by_total_vars', show_plot=True)

# %%
xcol="CHROM"
ycol="total_haplotypes"
plot_bar_hapstats(final_hap_df, xcol, ycol, filepath='chrome_by_total_haplotypes',show_plot=True)
